# %%
import numpy as np
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# Generating some example sequential data
sentences = ['I love learning','I love python','I hate school',
             'Recurrent Neural Networks are powerful']
# Tokenizing the words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)
total_words = len(tokenizer.word_index) + 1

# Creating input sequences and their corresponding next words
input_sequences = []
for sentence in sentences:
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        n_gram_sequence = tokenized_sentence[:i+1]
        input_sequences.append(n_gram_sequence)

# Padding sequences for consistent input size
max_sequence_length = max([len(seq) for seq in input_sequences])
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# Creating input and output data
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = to_categorical(y, num_classes=total_words)

# Building a simple RNN model
model = Sequential()
model.add(Embedding(input_dim=total_words, output_dim=50, input_length=max_sequence_length-1))
model.add(SimpleRNN(100, return_sequences=True))
model.add(SimpleRNN(100))
model.add(Dense(total_words, activation='softmax'))

# Compiling the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Training the model
model.fit(X, y, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 1/1 - 2s - loss: 2.5012 - accuracy: 0.1000 - 2s/epoch - 2s/step
# Epoch 2/50
# 1/1 - 0s - loss: 2.4123 - accuracy: 0.4000 - 21ms/epoch - 21ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 2.3276 - accuracy: 0.3000 - 16ms/epoch - 16ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 2.2435 - accuracy: 0.3000 - 13ms/epoch - 13ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 2.1582 - accuracy: 0.3000 - 13ms/epoch - 13ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 2.0712 - accuracy: 0.3000 - 13ms/epoch - 13ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 1.9835 - accuracy: 0.3000 - 23ms/epoch - 23ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 1.8966 - accuracy: 0.3000 - 16ms/epoch - 16ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 1.8122 - accuracy: 0.3000 - 12ms/epoch - 12ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 1.7309 - accuracy: 0.3000 - 10ms/epoch - 10ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 1.6519 - accuracy: 0.4000 - 14ms/epoch - 14ms/step
# Epoch 12/50
# 1/1 - 0s - loss: 1.5748 - accuracy: 0.4000 - 11ms/epoch - 11ms/step
# Epoch 13/50
# 1/1 - 0s - loss: 1.5005 - accuracy: 0.4000 - 13ms/epoch - 13ms/step
# Epoch 14/50
# 1/1 - 0s - loss: 1.4310 - accuracy: 0.6000 - 11ms/epoch - 11ms/step
# Epoch 15/50
# 1/1 - 0s - loss: 1.3678 - accuracy: 0.7000 - 10ms/epoch - 10ms/step
# Epoch 16/50
# 1/1 - 0s - loss: 1.3106 - accuracy: 0.7000 - 9ms/epoch - 9ms/step
# Epoch 17/50
# 1/1 - 0s - loss: 1.2574 - accuracy: 0.7000 - 20ms/epoch - 20ms/step
# Epoch 18/50
# 1/1 - 0s - loss: 1.2065 - accuracy: 0.7000 - 19ms/epoch - 19ms/step
# Epoch 19/50
# 1/1 - 0s - loss: 1.1577 - accuracy: 0.7000 - 25ms/epoch - 25ms/step
# Epoch 20/50
# 1/1 - 0s - loss: 1.1113 - accuracy: 0.7000 - 16ms/epoch - 16ms/step
# Epoch 21/50
# 1/1 - 0s - loss: 1.0675 - accuracy: 0.7000 - 12ms/epoch - 12ms/step
# Epoch 22/50
# 1/1 - 0s - loss: 1.0254 - accuracy: 0.7000 - 11ms/epoch - 11ms/step
# Epoch 23/50
# 1/1 - 0s - loss: 0.9842 - accuracy: 0.7000 - 11ms/epoch - 11ms/step
# Epoch 24/50
# 1/1 - 0s - loss: 0.9434 - accuracy: 0.6000 - 14ms/epoch - 14ms/step
# Epoch 25/50
# 1/1 - 0s - loss: 0.9037 - accuracy: 0.6000 - 19ms/epoch - 19ms/step
# Epoch 26/50
# 1/1 - 0s - loss: 0.8661 - accuracy: 0.6000 - 11ms/epoch - 11ms/step
# Epoch 27/50
# 1/1 - 0s - loss: 0.8309 - accuracy: 0.6000 - 11ms/epoch - 11ms/step
# Epoch 28/50
# 1/1 - 0s - loss: 0.7985 - accuracy: 0.7000 - 12ms/epoch - 12ms/step
# Epoch 29/50
# 1/1 - 0s - loss: 0.7690 - accuracy: 0.7000 - 11ms/epoch - 11ms/step
# Epoch 30/50
# 1/1 - 0s - loss: 0.7422 - accuracy: 0.7000 - 10ms/epoch - 10ms/step
# Epoch 31/50
# 1/1 - 0s - loss: 0.7181 - accuracy: 0.8000 - 10ms/epoch - 10ms/step
# Epoch 32/50
# 1/1 - 0s - loss: 0.6962 - accuracy: 0.8000 - 14ms/epoch - 14ms/step
# Epoch 33/50
# 1/1 - 0s - loss: 0.6760 - accuracy: 0.8000 - 14ms/epoch - 14ms/step
# Epoch 34/50
# 1/1 - 0s - loss: 0.6573 - accuracy: 0.8000 - 11ms/epoch - 11ms/step
# Epoch 35/50
# 1/1 - 0s - loss: 0.6399 - accuracy: 0.8000 - 15ms/epoch - 15ms/step
# Epoch 36/50
# 1/1 - 0s - loss: 0.6237 - accuracy: 0.8000 - 10ms/epoch - 10ms/step
# Epoch 37/50
# 1/1 - 0s - loss: 0.6084 - accuracy: 0.8000 - 10ms/epoch - 10ms/step
# Epoch 38/50
# 1/1 - 0s - loss: 0.5937 - accuracy: 0.8000 - 25ms/epoch - 25ms/step
# Epoch 39/50
# 1/1 - 0s - loss: 0.5793 - accuracy: 0.8000 - 14ms/epoch - 14ms/step
# Epoch 40/50
# 1/1 - 0s - loss: 0.5652 - accuracy: 0.8000 - 20ms/epoch - 20ms/step
# Epoch 41/50
# 1/1 - 0s - loss: 0.5517 - accuracy: 0.8000 - 16ms/epoch - 16ms/step
# Epoch 42/50
# 1/1 - 0s - loss: 0.5384 - accuracy: 0.8000 - 12ms/epoch - 12ms/step
# Epoch 43/50
# 1/1 - 0s - loss: 0.5254 - accuracy: 0.8000 - 11ms/epoch - 11ms/step
# Epoch 44/50
# 1/1 - 0s - loss: 0.5128 - accuracy: 0.8000 - 11ms/epoch - 11ms/step
# Epoch 45/50
# 1/1 - 0s - loss: 0.5004 - accuracy: 0.8000 - 12ms/epoch - 12ms/step
# Epoch 46/50
# 1/1 - 0s - loss: 0.4884 - accuracy: 0.8000 - 12ms/epoch - 12ms/step
# Epoch 47/50
# 1/1 - 0s - loss: 0.4768 - accuracy: 0.8000 - 13ms/epoch - 13ms/step
# Epoch 48/50
# 1/1 - 0s - loss: 0.4656 - accuracy: 0.8000 - 11ms/epoch - 11ms/step
# Epoch 49/50
# 1/1 - 0s - loss: 0.4549 - accuracy: 0.8000 - 11ms/epoch - 11ms/step
# Epoch 50/50
# 1/1 - 0s - loss: 0.4447 - accuracy: 0.8000 - 11ms/epoch - 11ms/step

# %%
# Generating text using the trained model
seed_text = input("Enter the starting word: ")
next_words = int(input("Enter how many words to predict: "))

for _ in range(next_words):
    tokenized_seed = tokenizer.texts_to_sequences([seed_text])[0]
    tokenized_seed = pad_sequences([tokenized_seed], maxlen=max_sequence_length-1, padding='pre')
    predicted_word_index = np.argmax(model.predict(tokenized_seed), axis=-1)
    predicted_word = tokenizer.index_word[predicted_word_index[0]]
    seed_text += " " + predicted_word

print(seed_text)
# Out:
# Enter the starting word: i love
# Enter how many words to predict: 5
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# i love learning hate are powerful are
